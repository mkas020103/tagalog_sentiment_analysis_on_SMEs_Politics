# %% [markdown]
# # model inference

# %%
import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
from classes import preprocess

folder_name = 'context base model v4/svm'
model = 'svm'
df_file = 'model'

# Preprocess the input text
maharlika = preprocess(df='raw data/Maharlika Fund.csv', added_stopwords='filipino_stopwords.csv', comment_column='Comment', dups=1)

x_test = maharlika.df['features_string_format']

# Load the SVM model
svm_model = joblib.load('{}/{}_model_context_base_{}.pkl'.format(folder_name, model, df_file))

# Load the vectorizer used during training
vectorizer = joblib.load('{}/{}_vectorizer_context_base_{}.pkl'.format(folder_name, model, df_file))

# Load the label encoder
label_encoder = joblib.load('{}/{}_label_encoder_context_base_{}.pkl'.format(folder_name, model, df_file))

# Apply the same vectorizer used in training to transform the test data
xtest_vectors = vectorizer.transform(x_test)

# Make predictions using the SVM model
predictions = svm_model.predict(xtest_vectors)

# Convert predictions to integer type
predictions = predictions.astype(int)

# Decode the predicted labels using the label encoder
decoded_predictions = label_encoder.inverse_transform(predictions)

# Print the predicted label
maharlika.df['context_base_prediction'] = decoded_predictions

# convert numeric value to sentiments
sentiment_dict = {
            1: 'neutral',
            2: 'positive',
            0: 'negative',
        }
maharlika.df['context_base_prediction'] = maharlika.df['context_base_prediction'].map(sentiment_dict)
# Out:
# Column Headers:  ['Comment', 'Comment Validation', 'Tally for total']
# shape of raw dataframe:  (531, 3)
# shape of dataframe when null comments were dropped:  (531, 5)
# shape of dataframe when preprocessed and duplicated values where dropped:  (492, 5)
# shape of final dataframe when rows that have null values where dropped:  (491, 5)

# %%
maharlika.df.head(20)
# Out:
#                                               Comment Comment Validation  \
# 0   hi sen pia sna po pauwiin nyu n si robin wla n...           Negative
# 1                                          Lage Naman           Negative
# 2    Correct ka jan, kasalanan ni bbm na Naman hahaha           Negative
# 3                                kasalanan to ni PBBM           Negative
# 4                             huh kwento mo sa pagong           Negative
# 5                            d puro project lang yarn           Negative
# 6                               Sus puro pasikat lang           Negative
# 7           dont even get me started on robin padilla           Negative
# 8                   Puro kase dilawan ang nasa Senado           Negative
# 9                          reject the maharlika funds           Negative
# 10                                 move on dilawan na           Negative
# 11                                       sino Loko mo           Negative
# 12  mga bobo talaga mga bias media takot lang mga ...           Negative
# 13                                           Mangmang           Negative
# 14  ni Hindi nga alam ni Marcos pano explain.. bul...           Negative
# 15  hnd n yng para sa taong bayan para sa knilang ...           Negative
# 16  bakit Di mo tanungin dilawan kelan sila Hindi ...           Negative
# 17  Hindi yan mararamdaman ng ordinaryong tao, un ...           Negative
# 18                       yung medea nayan dilawan yan           Negative
# 19  Magtaka kayo kung dilawan ang nasa puwesto, si...           Negative
#
#    Tally for total                                           features  \
# 0              NaN  [pia, sna, pauwiin, nyu, robin, wla, namn, ata...
# 1              NaN                                             [lage]
# 2              NaN                     [correct, jan, kasalanan, bbm]
# 3              NaN                                  [kasalanan, pbbm]
# 4              NaN                              [huh, kwento, pagong]
# 5              NaN                              [puro, project, yarn]
# 6              NaN                               [sus, puro, pasikat]
# 7              NaN         [dont, even, get, started, robin, padilla]
# 8              NaN                [puro, kase, dilawan, nasa, senado]
# 9              NaN                         [reject, maharlika, funds]
# 10             NaN                                    [move, dilawan]
# 11             NaN                                             [loko]
# 12             NaN                [bobo, bias, media, takot, dilawan]
# 13             NaN                                         [mangmang]
# 14             NaN  [hindi, alam, marcos, pano, explain, bulag, cr...
# 15             NaN  [hnd, yng, taong, bayan, knilang, bulsa, mappn...
# 16             NaN  [tanungin, dilawan, hindi, nsngurakot, taong, ...
# 17             NaN  [hindi, mararamdaman, ordinaryong, tao, taga, ...
# 18             NaN                            [medea, nayan, dilawan]
# 19             NaN  [magtaka, kayo, dilawan, nasa, puwesto, sigura...
#
#                                features_string_format context_base_prediction
# 0   pia sna pauwiin nyu robin wla namn ata ngagawa...                negative
# 1                                                lage                positive
# 2                           correct jan kasalanan bbm                negative
# 3                                      kasalanan pbbm                negative
# 4                                   huh kwento pagong                 neutral
# 5                                   puro project yarn                negative
# 6                                    sus puro pasikat                negative
# 7                 dont even get started robin padilla                negative
# 8                       puro kase dilawan nasa senado                negative
# 9                              reject maharlika funds                negative
# 10                                       move dilawan                negative
# 11                                               loko                 neutral
# 12                      bobo bias media takot dilawan                negative
# 13                                           mangmang                negative
# 14  hindi alam marcos pano explain bulag creator l...                negative
# 15  hnd yng taong bayan knilang bulsa mappnta fund...                negative
# 16  tanungin dilawan hindi nsngurakot taong bayan ...                negative
# 17  hindi mararamdaman ordinaryong tao taga suport...                negative
# 18                                medea nayan dilawan                negative
# 19  magtaka kayo dilawan nasa puwesto sigurado bul...                negative

# %%
maharlika.df['Comment Validation'].value_counts()
# Out:
# Neutral     419
# Positive     37
# Negative     35
# Name: Comment Validation, dtype: int64

# %%
maharlika.df['context_base_prediction'].value_counts()
# Out:
# negative    296
# positive    172
# neutral      23
# Name: context_base_prediction, dtype: int64

# %%
# 2 stands for positive, 1 for neutral, 0 for negative
