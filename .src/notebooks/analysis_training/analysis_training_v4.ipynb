# %% [markdown]
# # Walkthrough

# %% [raw]
# This program is used to call classes that are related to building the model and data visualization.
#
# Parameters of each class:
#     preprocess(df, added_stopwords, column: str, drop : list = None)
#         • df - Is the csv file to be preprocessed, must be in string format (filename).
#         • added_stopwords - Is the the csv file containing the words to be stopped, must be in string format (filename).
#         • column - Is the column in the dataframe that will be preprocessed.
#         • drop(optional) - Is the list column\s to be dropped.
#
#     eda(df, text_column_name: str, sent_column_name: str)
#         • df - Is a dataframe
#         • text_column_name - Is a column name that represents the columns of text. Used in wordcloud and average word number visualization.
#         • sent_column_name - Is a column name that represents the columns of sentiments. Used for sentiment visualization.
#     sentiment_analysis(df)
#         • df - Is a dataframe
#     LDA(df)
#         • df - Is a dataframe
#     KMeansClustering(df)
#         • df - Is a dataframe
#
# Usages:
#     x = preprocess(df, added_stopwords, column, drop) - preprocess the df
#
#     y = eda(x.df)
#     y.descriptions() - prints the basic descriptions of the dataframe
#
#     y.word_number() - prints the visualization for the average number of words
#
#     y.top_10words() - prints the top 10 words
#
#     y.bigrams() -  print the top 10 bigrams
#
#     y.english_tagalog() - print the bar graph of english and tagalog text
#
#     y.generate_wordcloud(filename, category, value) - print the wordcloud of all the text in the file. 'category' is optional if its not None generate the wordcloud in the specified category(column). 'value' must also be inputted, and it is the value in the 'category' column. Filename is just the name of the file you wanted to save the image.
#
#     y.plot_sentiment(column_name, filename) - 'filename' is the name of the image file you want to save. 'column_name' is the column containing the sentiments

# %%
import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np

# %%
from classes import preprocess, eda, LDA, KMeansClustering, sentiment_analysis, models
# Out:
# c:\users\mdfl0\appdata\local\programs\python\python39\lib\site-packages\past\builtins\misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mdfl0\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# shape of dataframe:  (5997, 3)
# shape of dataframe:  (5997, 5)

# %% [markdown]
# # Data preparation (with\out duplicates)

# %%
free_tuition = preprocess(df='raw data/Free Tuition Comments.csv',added_stopwords='freetuition_stopwords.csv', 
                                       sent_column=['CONTEXT-BASED'], 
                                       comment_column='Comment', dups=0, drop=['Video Link', 'Comment Image Rate'])
# Out:
# shape of dataframe:  (898, 5)
# shape of dataframe:  (898, 7)

# %%
free_tuition.df['Account'].value_counts()
# Out:
# jqcrypto              445
# papabiii               23
# cryptopareh            14
# pozlifewithleo         11
# mjaguilar_official      2
# nixsramos               1
# giucomia                1
# Name: Account, dtype: int64

# %%
free_tuition.df.head()
# Out:
#                                              Comment Comment type  \
# 0  free tuition nga, pero may grade req's. Pinipi...      neutral
# 1                    ngi bat ngayon molang alam haha      neutral
# 2  hala now niyo lang po nalaman . free tuition n...      neutral
# 3  sana madagdagan for nursing. isa sa mga pinaka...      neutral
# 4  Nastop ang UNIFAST now, SYC 2021-2022 up until...      neutral
#
#    CONTEXT-BASED   Account             Timestamp  \
# 0            1.0  jqcrypto  July 11, 2023, 21:21
# 1            1.0  jqcrypto  July 11, 2023, 21:21
# 2            2.0  jqcrypto  July 11, 2023, 21:21
# 3            1.0  jqcrypto  July 11, 2023, 21:21
# 4            1.0  jqcrypto  July 11, 2023, 21:21
#
#                                             features  \
# 0  [free, tuition, grade, reqs, pinipili, makpsok...
# 1                           [ngi, bat, molang, alam]
# 2  [hala, niyo, nalaman, free, tuition, tapos, bi...
# ...

# %% [markdown]
# # Non Duplicate values (context base)

# %% [markdown]
# ## Phase 1: Free tuition sentiments of jqcrypto's video

# %% [markdown]
# ### A. Facts and analysis

# %%
df1 = free_tuition.df[free_tuition.df['Account'] == 'jqcrypto']

# %%
df1['CONTEXT-BASED'].value_counts()
# Out:
# 1.0    219
# 2.0    157
# 0.0     59
# Name: CONTEXT-BASED, dtype: int64

# %%
eda_non_duplicates = eda(df1, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')

# %%
# total number of comments
eda_non_duplicates.df['features_string_format'].notnull().sum().sum()
# Out:
# 445

# %%
eda_non_duplicates.generate_wordcloud(filename='jqcrypto_all_comment_context_base_free_tuition')

# %%
eda_non_duplicates.generate_wordcloud('jqcrypto_negative_context_base_free_tution', 'CONTEXT-BASED', 0.0)

# %%
eda_non_duplicates.generate_wordcloud('jqcrypto_positive_context_base_free_tution', 'CONTEXT-BASED', 2.0)

# %%
eda_non_duplicates.generate_wordcloud('jqcrypto_neutral_context_base_free_tution', 'CONTEXT-BASED', 1.0)

# %%
eda_non_duplicates.pie_sentiment('jqcrypto_context_base_free_tution', 'CONTEXT-BASED')

# %%
eda_non_duplicates.bar_sentiment('jqcrypto_context_base_free_tution', 'CONTEXT-BASED')

# %%
# top 5 positive comments
x = df1[df1['CONTEXT-BASED'] == 2]
positive = eda(x, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
positive.top_words(7, 'positive', 'jqcrypto_positive_context_base_free_tution')

# %%
# top 5 positive bigrams
positive.bigrams(7, 'positive', 'jqcrypto_positive_context_base_free_tution')

# %%
# top 5 negative comments
x = df1[df1['CONTEXT-BASED'] == 0.0]
negative = eda(x, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
negative.top_words(7, 'negative', 'jqcrypto_negative_context_base_free_tution')

# %%
# top 5 negative bigrams 
negative.bigrams(7, 'negative', 'jqcrypto_negative_context_base_free_tution')

# %%
# top 5 neutral comments
z = df1[df1['CONTEXT-BASED'] == 1.0]
neutral = eda(z, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
neutral.top_words(7, 'neutral', 'jqcrypto_neutral_context_base_free_tution')

# %%
# top 5 negative comments _context_base_bam_related
neutral.bigrams(7, 'neutral', 'jqcrypto_neutral_context_base_free_tution')

# %% [markdown]
# ## Phase 1: Free tuition sentiments of papabiii's video

# %% [markdown]
# ### A. Facts and analysis

# %%
df2 = free_tuition.df[free_tuition.df['Account'] == 'papabiii']

# %%
df2['CONTEXT-BASED'].value_counts()
# Out:
# 1.0    9
# 0.0    7
# 2.0    7
# Name: CONTEXT-BASED, dtype: int64

# %%
eda_papabiii = eda(df2, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')

# %%
eda_papabiii.df['features_string_format'].notnull().sum().sum()
# Out:
# 23

# %%
eda_papabiii.generate_wordcloud(filename='papabiii_all_comment_context_base_free_tuition')

# %%
eda_papabiii.generate_wordcloud('papabiii_negative_context_base_free_tution', 'CONTEXT-BASED', 0.0)

# %%
eda_papabiii.generate_wordcloud('papabiii_positive_context_base_free_tution', 'CONTEXT-BASED', 2.0)

# %%
eda_papabiii.generate_wordcloud('papabiii_neutral_context_base_free_tution', 'CONTEXT-BASED', 1.0)

# %%
eda_papabiii.pie_sentiment('papabiii_context_base_free_tution', 'CONTEXT-BASED')

# %%
eda_papabiii.bar_sentiment('papabiii_context_base_free_tution', 'CONTEXT-BASED')

# %%
# top 7 positive comments
x = df2[df2['CONTEXT-BASED'] == 2]
positive = eda(x, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
positive.top_words(7, 'positive', 'papabiii_positive_context_base_free_tution')

# %%
# top 7 positive bigrams
positive.bigrams(7, 'positive', 'papabiii_positive_context_base_free_tution')

# %%
# top 7 negative comments
x = df2[df2['CONTEXT-BASED'] == 0.0]
negative = eda(x, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
negative.top_words(7, 'negative', 'papabiii_negative_context_base_free_tution')

# %%
# top 7 negative bigrams 
negative.bigrams(7, 'negative', 'papabiii_negative_context_base_free_tution')

# %%
# top 7 neutral comments
z = df2[df2['CONTEXT-BASED'] == 1.0]
neutral = eda(z, text_column_name='features_string_format', sent_column_name='CONTEXT-BASED')
neutral.top_words(7, 'neutral', 'papabiii_neutral_context_base_free_tution')

# %%
# top 7 negative comments _context_base_bam_related
neutral.bigrams(7, 'neutral', 'papabiii_neutral_context_base_free_tution')

# %% [markdown]
# # Train the model and analyse the data

# %%
df = pd.read_csv('balanced_data_context3.9k.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                            Comment  category
# 0         758                                                rin       1.0
# 1          43                               omg embarassing shet       1.0
# 2         721                                quality worth price       1.0
# 3         652                              san meron naic ganyan       1.0
# 4         306  nothing special need vga cable cctv system mon...       1.0

# %%
# create a model for related to bam and context based
x = models(df=df, x='Comment', y='category', filename='context_base_free_tuition')

# %%
x.svm()

# %%
x.evaluate_model()
# Out:
# svm or dectree
# Accuracy: 0.7115384615384616
# F1 score (micro): 0.7115384615384616
# F1 score (macro): 0.7133506555941822
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.64       260
#            1       0.88      0.81      0.84       260
#            2       0.62      0.72      0.66       260
#
#     accuracy                           0.71       780
#    macro avg       0.72      0.71      0.71       780
# weighted avg       0.72      0.71      0.71       780

# %%
y = models(df=df, x='Comment', y='category', filename='context_base_free_tuition')

# %%
y.decision_tree()

# %%
y.evaluate_model()
# Out:
# svm or dectree
# Accuracy: 0.6192307692307693
# F1 score (micro): 0.6192307692307693
# F1 score (macro): 0.6133507974395619
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61       260
#            1       0.71      0.74      0.72       260
#            2       0.61      0.43      0.51       260
#
#     accuracy                           0.62       780
#    macro avg       0.62      0.62      0.61       780
# weighted avg       0.62      0.62      0.61       780

# %%
z = models(df=df, x='Comment', y='category', filename='context_base_free_tuition')

# %%
z.random_forest()

# %%
z.evaluate_model()
# Out:
# svm or dectree
# Accuracy: 0.6858974358974359
# F1 score (micro): 0.6858974358974359
# F1 score (macro): 0.6833452601319694
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62       260
#            1       0.75      0.82      0.78       260
#            2       0.63      0.67      0.65       260
#
#     accuracy                           0.69       780
#    macro avg       0.68      0.69      0.68       780
# weighted avg       0.68      0.69      0.68       780

# %%
# end of program
